# %%
import pandas as pd
import kagglehub

# %%
path = kagglehub.dataset_download("kaggle/sf-salaries")

# %%
print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/sf-salaries

# %%
data = pd.read_csv('/root/.cache/kagglehub/datasets/kaggle/sf-salaries/versions/5/Salaries.csv')
# Out:
# /tmp/ipython-input-2177249237.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/root/.cache/kagglehub/datasets/kaggle/sf-salaries/versions/5/Salaries.csv')

# %%
import os

# List files in the downloaded directory
downloaded_path = "/root/.cache/kagglehub/datasets/kaggle/sf-salaries/versions/5"
print(os.listdir(downloaded_path))
# Out:
# ['Salaries.csv', 'database.sqlite']

# %% [markdown]
# <h4> Display Top 10 Rows of The Dataset

# %%
data.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %% [markdown]
# <h4>Check Last 10 Rows of The Dataset

# %%
data.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %% [markdown]
# <h4>Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
data.shape
# Out:
# (148654, 13)

# %%
print("Number of rows:", data.shape[0])
print("Number of columns:", data.shape[1])
# Out:
# Number of rows: 148654
# Number of columns: 13

# %% [markdown]
# <h4> Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %% [markdown]
# <h4>Check Null Values In The Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
data.isna().sum()
data.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %% [markdown]
# Drop ID, Notes, Agency, and Status Columns

# %%
data.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
data.drop(['Id','Notes','Agency','Status'],axis =1, inplace=True)

# %%
data
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#              BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# ...

# %% [markdown]
# Checking headmap

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# <h4>Get Overall Statistics About The Dataframe

# %%
data.describe()
# Out:
#             TotalPay  TotalPayBenefits           Year
# count  148654.000000     148654.000000  148654.000000
# mean    74768.321972      93692.554811    2012.522643
# std     50517.005274      62793.533483       1.117538
# min      -618.130000       -618.130000    2011.000000
# 25%     36168.995000      44065.650000    2012.000000
# 50%     71426.610000      92404.090000    2013.000000
# 75%    105839.135000     132876.450000    2014.000000
# max    567595.430000     567595.430000    2014.000000

# %%
data.describe(include='all')
# Out:
#        EmployeeName          JobTitle   BasePay  OvertimePay  OtherPay  \
# count        148654            148654  148049.0     148654.0  148654.0
# unique       110811              2159  109900.0      66555.0   84968.0
# top       Kevin Lee  Transit Operator       0.0          0.0       0.0
# freq             13              7036     875.0      66103.0   35218.0
# mean            NaN               NaN       NaN          NaN       NaN
# std             NaN               NaN       NaN          NaN       NaN
# min             NaN               NaN       NaN          NaN       NaN
# 25%             NaN               NaN       NaN          NaN       NaN
# 50%             NaN               NaN       NaN          NaN       NaN
# 75%             NaN               NaN       NaN          NaN       NaN
# max             NaN               NaN       NaN          NaN       NaN
#
#         Benefits       TotalPay  TotalPayBenefits           Year
# ...

# %% [markdown]
# <h4>Find Occurrence of The Employee Names  (Top 5)

# %%
data['EmployeeName'].value_counts().head()  #top 5 most occuring Data
# Out:
# EmployeeName
# Kevin Lee       13
# William Wong    11
# Richard Lee     11
# Steven Lee      11
# John Chan        9
# Name: count, dtype: int64

# %% [markdown]
# Find The Number of Unique Job Titles

# %%
data['JobTitle'].nunique() #unique values in every column
# Out:
# 2159

# %% [markdown]
# Total Number of Job Titles Contain Captain

# %%
data[data['JobTitle'].str.contains('Captain')] #job title having Captain and total no
# Out:
#               EmployeeName                   JobTitle    BasePay OvertimePay  \
# 36167        John Goldberg                  Captain 3   104404.0         0.0
# 36180     Michael Rolovich  Captain, Fire Suppression  145659.03   125868.06
# 36184        Darryl Hunter  Captain, Fire Suppression  145659.03   115673.73
# 36186       Michael Delane  Captain, Fire Suppression  147069.71   113372.94
# 36189       Philip Stevens  Captain, Fire Suppression   124573.5    53895.92
# ...                    ...                        ...        ...         ...
# 116604   Gregory L Stewart  Captain, Fire Suppression   73355.21    18517.18
# 120867     Michael J Moran                  Captain 3     7660.0     1496.09
# 122361  Michael V Rolovich  Captain, Fire Suppression        0.0         0.0
# 126588    Stephen M Tittel                  Captain 3   68491.89         0.0
# 132232     Jeanne M Seyler  Captain, Fire Suppression   61039.43     2285.30
#
# ...

# %%
len(data[data['JobTitle'].str.contains('Captain')])
# Out:
# 411

# %%
data[data['JobTitle'].str.contains('Manager')].count() #job title having Manager
# Out:
# EmployeeName        3080
# JobTitle            3080
# BasePay             3067
# OvertimePay         3080
# OtherPay            3080
# Benefits            3080
# TotalPay            3080
# TotalPayBenefits    3080
# Year                3080
# dtype: int64

# %%
len(data[data['JobTitle'].str.contains('Manager')].count()) #job title having Manager
# Out:
# 9

# %% [markdown]
# Display All the Employee Names From Fire Department

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data[data['JobTitle'].str.contains('Fire')]
# Out:
#               EmployeeName                        JobTitle    BasePay  \
# 36159       Gary Altenberg    Lieutenant, Fire Suppression  128808.87
# 36162   Joanne Hayes-White          Chief, Fire Department  296943.01
# 36163    Frederick Binkley       EMT/Paramedic/Firefighter  126863.19
# 36168       David Franklin    Asst Chf of Dept (Fire Dept)  204032.52
# 36169         Brendan Ward  Battlion Chief, Fire Suppressi  174822.47
# ...                    ...                             ...        ...
# 145956    Kenneth C Farris                     Firefighter       0.00
# 147556       Edward A Dunn                     Firefighter    1063.24
# 148021      Kari A Johnson                     Firefighter     688.71
# 148209        Sheryl K Lee                     Firefighter     459.14
# 148554     Lawrence F Gatt           Fire Alarm Dispatcher      73.33
#
#        OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  Year
# ...

# %%
data[data['JobTitle'].str.contains('Fire',case=False)]['EmployeeName']
# Out:
# 4            PATRICK GARDNER
# 6                  ALSON LEE
# 8             MICHAEL MORRIS
# 9         JOANNE HAYES-WHITE
# 10             ARTHUR KENNEY
#                  ...
# 145956      Kenneth C Farris
# 147556         Edward A Dunn
# 148021        Kari A Johnson
# 148209          Sheryl K Lee
# 148554       Lawrence F Gatt
# Name: EmployeeName, Length: 5879, dtype: object

# %% [markdown]
#  Find Minimum, Maximum, and Average BasePay

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   EmployeeName      148654 non-null  object
#  1   JobTitle          148654 non-null  object
#  2   BasePay           148049 non-null  object
#  3   OvertimePay       148654 non-null  object
#  4   OtherPay          148654 non-null  object
#  5   Benefits          112495 non-null  object
#  6   TotalPay          148654 non-null  float64
#  7   TotalPayBenefits  148654 non-null  float64
#  8   Year              148654 non-null  int64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 10.2+ MB

# %%
#data['BasePay'] = data['BasePay'].astype(int) #converting but failed due to null values

# %%
data['BasePay'] = pd.to_numeric(data['BasePay'], errors='coerce') #converting to int by taking null as NAN we
#we can ignore null by errors = 'ignore' but it will not perform calculations so

# %%
data['BasePay'].mean() #average
# Out:
# np.float64(66325.4488404877)

# %%
data['BasePay'].min()
# Out:
# -166.01

# %%
data['BasePay'].max()
# Out:
# 319275.01

# %% [markdown]
# <h4>Replace 'Not Provided' in EmployeeName' Column to NaN </h4>

# %%
import numpy as np

# %%
data['EmployeeName'].replace('Not provided', np.nan, inplace=True)
# Out:
# /tmp/ipython-input-2689621018.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['EmployeeName'].replace('Not provided', np.nan, inplace=True)

# %%
data
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650                NaN                                    Not provided
# 148651                NaN                                    Not provided
# 148652                NaN                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# ...

# %% [markdown]
# <h4>Drop The Rows Having 5 Missing Values</h4>

# %%
data[data.isnull().sum(axis=1)==3]  #rows where 5 values are null
# Out:
# Empty DataFrame
# Columns: [EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year]
# Index: []

# %%
data.drop(data[data.isnull().sum(axis=1)==5].index, axis=0, inplace=True)

# %% [markdown]
# <h4>Find Job Title of ALBERT PARDINI</h4>

# %%
data[data['EmployeeName'] == 'ALBERT PARDINI']['JobTitle']
# Out:
# 2    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %% [markdown]
# <h4>How Much ALBERT PARDINI Make (Include Benefits)?

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data[data['EmployeeName'] == 'ALBERT PARDINI']['Benefits']
# Out:
# 2    NaN
# Name: Benefits, dtype: object

# %%
data[data['EmployeeName'] == 'ALBERT PARDINI']['TotalPay' + 'Benefits']
# Out:
# 2    335279.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# <h4>Display Name of The Person Having The Highest BasePay

# %%
emp = data['BasePay'].max()

# %%
data[data['BasePay']==emp]['EmployeeName']
# Out:
# 72925    Gregory P Suhr
# Name: EmployeeName, dtype: object

# %% [markdown]
# <h4>Find Average BasePay of All Employee Per Year

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data['BasePay']
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
#             ...
# 148649         0.00
# 148650          NaN
# 148651          NaN
# 148652          NaN
# 148653         0.00
# Name: BasePay, Length: 148654, dtype: float64

# %%
data['Year'] = data['Year'].astype(int)

# %%
data['BasePay'].replace('NaN',np.nan)
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
#             ...
# 148649         0.00
# 148650          NaN
# 148651          NaN
# 148652          NaN
# 148653         0.00
# Name: BasePay, Length: 148654, dtype: float64

# %%
data['BasePay'] = pd.to_numeric(data['BasePay'], errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   EmployeeName      148650 non-null  object
#  1   JobTitle          148654 non-null  object
#  2   BasePay           148045 non-null  float64
#  3   OvertimePay       148654 non-null  object
#  4   OtherPay          148654 non-null  object
#  5   Benefits          112495 non-null  object
#  6   TotalPay          148654 non-null  float64
#  7   TotalPayBenefits  148654 non-null  float64
#  8   Year              148654 non-null  int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 10.2+ MB

# %%
data.groupby('Year')['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# <h4>Find Average BasePay of All Employee Per JobTitle

# %%
data.groupby('JobTitle')['BasePay'].mean()
# Out:
# JobTitle
# ACCOUNT CLERK                                     43300.806506
# ACCOUNTANT                                        46643.172000
# ACCOUNTANT INTERN                                 28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                       62290.780000
# ACUPUNCTURIST                                     66374.400000
#                                                       ...
# X-RAY LABORATORY AIDE                             47664.773077
# X-Ray Laboratory Aide                             46086.387100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.910000
# Youth Comm Advisor                                39077.957500
# ZOO CURATOR                                       43148.000000
# Name: BasePay, Length: 2159, dtype: float64

# %% [markdown]
# <h4>Find Average BasePay of Employee Having Job Title ACCOUNTANT

# %%
data.groupby('JobTitle')['BasePay'].mean()['ACCOUNTANT']
# Out:
# np.float64(46643.172)

# %% [markdown]
# <h4>Find Top 5 Most Common Jobs

# %%
data['JobTitle'].value_counts().head()
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %% [markdown]
# From video on Youtube [Video](https://www.youtube.com/watch?v=qbW8AqEpLtU&list=PL_1pt6K-CLoDMEbYy2PcZuITWEjqMfyoA&index=3)
